# %% [markdown]
# # load website in tkinter frame

# %%
import tkinterweb as t

# %%
dir(t.HtmlFrame)
# Out:
# ['_Misc__winfo_getint',
#  '_Misc__winfo_parseitem',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bind',
#  '_configure',
#  '_displayof',
#  '_do',
#  '_getboolean',
#  '_getconfigure',
#  '_getconfigure1',
#  '_getdoubles',
#  '_getints',
#  '_grid_configure',
#  '_gridconvvalue',
#  '_last_child_ids',
#  '_nametowidget',
#  '_noarg_',
#  '_options',
#  '_register',
#  '_report_exception',
#  '_root',
#  '_setup',
#  '_subst_format',
#  '_subst_format_str',
#  '_substitute',
#  '_tclCommands',
#  '_windowingsystem',
#  'add_css',
#  'add_html',
#  'add_visited_links',
# ...

# %%
from tkinterweb import HtmlFrame #import the HTML browser
try:
  import tkinter as tk #python3
except ImportError:
  import Tkinter as tk #python2

root = tk.Tk() #create the tkinter window
frame = HtmlFrame(root) #create HTML browser

frame.load_website("http://tkhtml.tcl.tk/tkhtml.html") #load a website
frame.pack(fill="both", expand=True) #attach the HtmlFrame widget to the parent window
root.mainloop()
# Out:
# Starting TkinterWeb for 64-bit Windows with Python 3.6.5.
#
# Tkhtml3 successfully loaded from c:\users\hp\appdata\local\programs\python\python36\lib\site-packages\tkinterweb\tkhtml\Windows\64-bit.
#
# Welcome to TkinterWeb 3.10!
# https://github.com/Andereoo/TkinterWeb
#
# Debugging messages are enabled.
# Use the parameter `messages_enabled = False` when calling HtmlFrame() to disable these messages.
#
# Connecting to tkhtml.tcl.tk.
#
# Loading stylesheet from http://tkhtml.tcl.tk/tkhtml_tcl_tk.css.
#
# A link to 'http://tkhtml.tcl.tk/support.html' has been clicked.
#
# Connecting to tkhtml.tcl.tk.
#
# Loading stylesheet from http://tkhtml.tcl.tk/tkhtml_tcl_tk.css.
#
# A link to 'http://tkhtml.tcl.tk/index.html' has been clicked.
#
# Connecting to tkhtml.tcl.tk.
#
# Loading stylesheet from http://tkhtml.tcl.tk/tkhtml_tcl_tk.css.
#
# A link to 'http://tkhtml.tcl.tk/hv3_widget.html' has been clicked.
#
# Connecting to tkhtml.tcl.tk.
#
# ...

# %%
from tkinterweb import HtmlFrame #import the HTML browser
try:
  import tkinter as tk #python3
except ImportError:
  import Tkinter as tk #python2

root = tk.Tk() #create the tkinter window
frame = HtmlFrame(root) #create HTML browser

frame.load_website("https://mis.santukatransport.in/") #load a website
frame.pack(fill="both", expand=True) #attach the HtmlFrame widget to the parent window
root.mainloop()
# Out:
# Starting TkinterWeb for 64-bit Windows with Python 3.6.5.
#
# Tkhtml3 successfully loaded from c:\users\hp\appdata\local\programs\python\python36\lib\site-packages\tkinterweb\tkhtml\Windows\64-bit.
#
# Welcome to TkinterWeb 3.10!
# https://github.com/Andereoo/TkinterWeb
#
# Debugging messages are enabled.
# Use the parameter `messages_enabled = False` when calling HtmlFrame() to disable these messages.
#
# Connecting to mis.santukatransport.in.
#
# Loading stylesheet from https://mis.santukatransport.in/Content/font-open-sans.css?v=_lyM_7sDAZstbPZ6aTr8rQ2.
#
# Loading stylesheet from https://mis.santukatransport.in/Content/font-awesome.css?v=U0PuGih6Zf8glhR2_YphiA2.
#
# Loading stylesheet from https://mis.santukatransport.in/Content/simple-line-icons.css?v=U08-bGFZbm-SCdpCiKiQFQ2.
#
# Loading stylesheet from https://mis.santukatransport.in/Content/ionicons.css?v=8nNUsorzz0jSgmDAMwXQzg2.
#
# ...

# %%
from tkinterweb import HtmlFrame #import the HTML browser
try:
  import tkinter as tk #python3
except ImportError:
  import Tkinter as tk #python2

root = tk.Tk() #create the tkinter window
frame = HtmlFrame(root) #create HTML browser

frame.load_website("youtube.com") #load a website
frame.pack(fill="both", expand=True) #attach the HtmlFrame widget to the parent window
root.mainloop()
# Out:
# Starting TkinterWeb for 64-bit Windows with Python 3.6.5.
#
# Tkhtml3 successfully loaded from c:\users\hp\appdata\local\programs\python\python36\lib\site-packages\tkinterweb\tkhtml\Windows\64-bit.
#
# Welcome to TkinterWeb 3.10!
# https://github.com/Andereoo/TkinterWeb
#
# Debugging messages are enabled.
# Use the parameter `messages_enabled = False` when calling HtmlFrame() to disable these messages.
#
# Connecting to youtube.com.
#
# Loading stylesheet from https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;500;700&family=YouTube+Sans:wght@300..9....
#
# Loading stylesheet from https://www.youtube.com/s/desktop/c545f464/cssbin/www-main-desktop-home-page-skeleton.css.
#
# Loading stylesheet from https://www.youtube.com/s/desktop/c545f464/cssbin/www-onepick.css.
#
# Loading <style> element.
#
# Loading <style> element.
#
# Loading <style> element.
#
# Loading <style> element.
#
# Loading <style> element.
#
# Loading <iframe> element.
#
# Connecting to accounts.google.com.
# ...

# %%
# !pip install ScrollableFrame

# %% [markdown]
# # tkinter scrollbar

# %%
from tkinter import *
from ScrollableFrame import *

root = Tk()
# It's no different from tkinter's Frame,
# orient(The orient of scroolbar): 0 -> VERTICAL, 1->HORIZONTAL, 2->both
sf = ScrollableFrame(root, orient = 0 , height=180, width=360) # :-)
Label(sf.frame, text=("(^_^)"*20+'\n')*20).pack()
sf.pack()
root.mainloop()

# %%
# !pip install tksheet
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for tksheet: filename=tksheet-5.3.8-py3-none-any.whl size=91759 sha256=b1d260d435424c5b7bcffb624a8304b183b63079b3a0a34b9b5aab54136453d5
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\d1\00\b9\fac23695ba5c078069f274d26679b260fb09a889892c08f94b
# Successfully built tksheet
# ...

# %%
from tkinter import *
from tksheet import Sheet

root = Tk()
sf = Sheet(root)
sf.add_row_selection(["shani","amit",])
sf.pack()
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-5dc0abd99064> in <module>
#       4 root = Tk()
#       5 sf = Sheet(root)
# ----> 6 sf.add_row_selection(["shani","amit",])
#       7 sf.pack()
#       8 root.mainloop()
#
# c:\users\hp\appdata\local\programs\python\python36\lib\site-packages\tksheet\_tksheet.py in add_row_selection(self, row, redraw, run_binding_func, set_as_current)
#    1156
#    1157     def add_row_selection(self, row, redraw = True, run_binding_func = True, set_as_current = True):
# -> 1158         self.RI.add_selection(r = row, redraw = redraw, run_binding_func = run_binding_func, set_as_current = set_as_current)
#    1159
#    1160     def add_column_selection(self, column, redraw = True, run_binding_func = True, set_as_current = True):
#
# ...
