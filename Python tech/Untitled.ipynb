# %%
import pytesseract as py

# %%
img="a.jpg"

# %%
from PIL import  Image

# %%
value=Image.open("a.jpg")

# %%
value
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=638x479 at 0x188BEBA1D30>

# %%
text=py.image_to_string(value)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python36\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     233     try:
# --> 234         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     235     except OSError as e:
#
# c:\users\hp\appdata\local\programs\python\python36\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#
# ...
